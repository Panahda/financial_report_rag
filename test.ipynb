# %%
from pathlib import Path
from natsort import natsorted
pdf_dir = Path("data/all")

# Get all PDF files

pdf_files = list(pdf_dir.glob("*.pdf"))
sorted_files = natsorted(pdf_files)
print((sorted_files))
# Out:
# [PosixPath('data/all/VCS_1_1.pdf'), PosixPath('data/all/VCS_1_2.pdf'), PosixPath('data/all/VCS_4_1.pdf'), PosixPath('data/all/VCS_4_2.pdf'), PosixPath('data/all/VCS_5_1.pdf'), PosixPath('data/all/VCS_5_2.pdf'), PosixPath('data/all/VCS_5_3.pdf'), PosixPath('data/all/VCS_5_4.pdf'), PosixPath('data/all/VCS_5_5.pdf'), PosixPath('data/all/VCS_5_6.pdf'), PosixPath('data/all/VCS_5_7.pdf'), PosixPath('data/all/VCS_5_8.pdf'), PosixPath('data/all/VCS_5_9.pdf'), PosixPath('data/all/VCS_5_10.pdf'), PosixPath('data/all/VCS_5_11.pdf'), PosixPath('data/all/VCS_5_12.pdf'), PosixPath('data/all/VCS_5_13.pdf'), PosixPath('data/all/VCS_6_1.pdf'), PosixPath('data/all/VCS_6_2.pdf'), PosixPath('data/all/VCS_6_3.pdf'), PosixPath('data/all/VCS_7_1.pdf'), PosixPath('data/all/VCS_7_2.pdf'), PosixPath('data/all/VCS_8_1.pdf'), PosixPath('data/all/VCS_8_2.pdf'), PosixPath('data/all/VCS_10_1.pdf'), PosixPath('data/all/VCS_10_2.pdf'), PosixPath('data/all/VCS_10_3.pdf'), PosixPath('data/all/VCS_10_4.pdf'), PosixPath
# ...
